# %%
import pandas as pd
import numpy as np

# %%
county_facts = "county_facts.csv"
primary_results = "primary_results.csv"
#primary_inverse = "fips_index.csv"

# %%
county_facts_df = pd.read_csv(county_facts, encoding="ISO-8859-1")
primary_results_df = pd.read_csv(primary_results, encoding="ISO-8859-1")
#primary_inverse = pd.read_csv(primary_inverse, encoding="ISO-8859-1")

# %%
# County facts dataframe
county_facts_df.head()
# Out:
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 0     0   United States                NaN  318857056  308758105        3.3
# 1  1000         Alabama                NaN    4849377    4780127        1.4
# 2  1001  Autauga County                 AL      55395      54571        1.5
# 3  1003  Baldwin County                 AL     200111     182265        9.8
# 4  1005  Barbour County                 AL      26887      27457       -2.1
#
#    POP010210  AGE135214  AGE295214  AGE775214    ...      SBO415207  \
# 0  308745538        6.2       23.1       14.5    ...            8.3
# 1    4779736        6.1       22.8       15.3    ...            1.2
# 2      54571        6.0       25.2       13.8    ...            0.7
# 3     182265        5.6       22.2       18.7    ...            1.3
# 4      27457        5.7       21.2       16.5    ...            0.0
#
#    SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# 0       28.8  5319456312  4174286516  3917663456      12990  613795732
# 1       28.1   112858843    52252752    57344851      12364    6426342
# 2       31.7           0           0      598175      12003      88157
# 3       27.3     1410273           0     2966489      17166     436955
# 4       27.0           0           0      188337       6334          0
#
#    BPS030214   LND110210  POP060210
# 0    1046363  3531905.43       87.4
# 1      13369    50645.33       94.4
# 2        131      594.44       91.8
# 3       1384     1589.78      114.6
# 4          8      884.88       31.0
#
# [5 rows x 54 columns]

# %%
#county_facts_df.count()

# %%
# Remove all NaN
county_facts_df = county_facts_df.dropna(how='any')

# Set dataframe to show specific columns
county_facts_cleaned_df = county_facts_df[["fips", "area_name", "PST120214", "POP010210", "POP645213", "VET605213", 
                                   "LFE305213", "INC110213", "PVY020213", "SBO001207", "SBO315207", "SBO215207",
                                  "SBO415207", "SBO015207", "MAN450207", "RTN130207", "RTN131207", "BPS030214", 
                                   "LND110210", "POP060210"]]
county_facts_cleaned_df.head()
# Out:
#    fips       area_name  PST120214  POP010210  POP645213  VET605213  \
# 2  1001  Autauga County        1.5      54571        1.6       5922
# 3  1003  Baldwin County        9.8     182265        3.6      19346
# 4  1005  Barbour County       -2.1      27457        2.9       2120
# 5  1007     Bibb County       -1.8      22915        1.2       1327
# 6  1009   Blount County        0.7      57322        4.3       4540
#
#    LFE305213  INC110213  PVY020213  SBO001207  SBO315207  SBO215207  \
# 2       26.2      53682       12.1       4067       15.2        1.3
# 3       25.9      50221       13.9      19035        2.7        1.0
# 4       24.6      32911       26.7       1667        0.0        0.0
# 5       27.6      36447       18.1       1385       14.9        0.0
# 6       33.9      44145       15.8       4458        0.0        0.0
#
#    SBO415207  SBO015207  MAN450207  RTN130207  RTN131207  BPS030214  \
# 2        0.7       31.7          0     598175      12003        131
# 3        1.3       27.3    1410273    2966489      17166       1384
# 4        0.0       27.0          0     188337       6334          8
# 5        0.0        0.0          0     124707       5804         19
# 6        0.0       23.2     341544     319700       5622          3
#
#    LND110210  POP060210
# 2     594.44       91.8
# 3    1589.78      114.6
# 4     884.88       31.0
# 5     622.58       36.8
# 6     644.78       88.9

# %%
# Rename columns
county_facts_cleaned_df = county_facts_cleaned_df.rename(columns={"area_name":"County", 
                                                  "PST120214":"Population % Change", 
                                                  "POP010210":"2010 Population", 
                                                  "POP645213":"% Foreign Born", 
                                                  "VET605213":"Veterans",
                                                  "LFE305213":"Mean Travel Time", 
                                                  "INC110213":"Median Household Income", 
                                                  "PVY020213":"Below Poverty Level", 
                                                  "SBO001207":"Total Number of Firms", 
                                                  "SBO315207":"% Black-owned Firms", 
                                                  "SBO215207":"% Asian-owned Firms",
                                                  "SBO415207":"% Hispanic-owned Firms", 
                                                  "SBO015207":"% Women-owned Firms", 
                                                  "MAN450207":"Manufacturers Shipments ($1000)", 
                                                  "RTN130207":"Retail Sales ($1000)",
                                                  "RTN131207":"Retail Sales per Capita",
                                                  "BPS030214":"Building permits",
                                                  "LND110210":"Land Area (Square Miles)", 
                                                  "POP060210":"Population per Square Mile"})
county_facts_cleaned_df.head()
# Out:
#    fips          County  Population % Change  2010 Population  % Foreign Born  \
# 2  1001  Autauga County                  1.5            54571             1.6
# 3  1003  Baldwin County                  9.8           182265             3.6
# 4  1005  Barbour County                 -2.1            27457             2.9
# 5  1007     Bibb County                 -1.8            22915             1.2
# 6  1009   Blount County                  0.7            57322             4.3
#
#    Veterans  Mean Travel Time  Median Household Income  Below Poverty Level  \
# 2      5922              26.2                    53682                 12.1
# 3     19346              25.9                    50221                 13.9
# 4      2120              24.6                    32911                 26.7
# 5      1327              27.6                    36447                 18.1
# 6      4540              33.9                    44145                 15.8
#
#    Total Number of Firms  % Black-owned Firms  % Asian-owned Firms  \
# 2                   4067                 15.2                  1.3
# 3                  19035                  2.7                  1.0
# 4                   1667                  0.0                  0.0
# 5                   1385                 14.9                  0.0
# 6                   4458                  0.0                  0.0
#
#    % Hispanic-owned Firms  % Women-owned Firms  \
# 2                     0.7                 31.7
# 3                     1.3                 27.3
# 4                     0.0                 27.0
# 5                     0.0                  0.0
# 6                     0.0                 23.2
#
#    Manufacturers Shipments ($1000)  Retail Sales ($1000)  \
# 2                                0                598175
# 3                          1410273               2966489
# 4                                0                188337
# 5                                0                124707
# 6                           341544                319700
#
#    Retail Sales per Capita  Building permits  Land Area (Square Miles)  \
# 2                    12003               131                    594.44
# 3                    17166              1384                   1589.78
# 4                     6334                 8                    884.88
# 5                     5804                19                    622.58
# 6                     5622                 3                    644.78
#
#    Population per Square Mile
# 2                        91.8
# 3                       114.6
# 4                        31.0
# 5                        36.8
# 6                        88.9

# %%
#qqq = pd.pivot_table(county_facts_cleaned_df, values='D', index=['A', 'B'],
#...                     columns=['C'], aggfunc=np.sum)

# %%
# Drop all NaN from primary results dataframe
primary_results_df = primary_results_df.dropna(how='any')

# %%
# Set dataframe to show specific columns
primary_results_cleaned_df = primary_results_df[["fips", "party", "candidate", "votes", "fraction_votes"]]

# %%
# Rename columns
primary_results_cleaned_df = primary_results_cleaned_df.rename(columns={"party":"Party",
                                                                       "candidate":"Candidate",
                                                                       "votes":"Votes",})

# %%
len(primary_results_cleaned_df)
# Out:
# 24511

# %%
primary_results_cleaned_df.head()
# Out:
#      fips     Party        Candidate  Votes  fraction_votes
# 0  1001.0  Democrat   Bernie Sanders    544           0.182
# 1  1001.0  Democrat  Hillary Clinton   2387           0.800
# 2  1003.0  Democrat   Bernie Sanders   2694           0.329
# 3  1003.0  Democrat  Hillary Clinton   5290           0.647
# 4  1005.0  Democrat   Bernie Sanders    222           0.078

# %%
aaa = primary_results_cleaned_df.set_index('fips')
aaa.head()
# Out:
#            Party        Candidate  Votes  fraction_votes
# fips
# 1001.0  Democrat   Bernie Sanders    544           0.182
# 1001.0  Democrat  Hillary Clinton   2387           0.800
# 1003.0  Democrat   Bernie Sanders   2694           0.329
# 1003.0  Democrat  Hillary Clinton   5290           0.647
# 1005.0  Democrat   Bernie Sanders    222           0.078

# %%
aaaa = pd.pivot_table(aaa, values= ["Votes", "Party"], index=['fips'], columns=["Candidate"], fill_value=0)
aaaa.head()
# Out:
#                    Votes                                                       \
# Candidate  No Preference  Uncommitted Ben Carson Bernie Sanders Carly Fiorina
# fips
# 1001.0                 0            0       1764            544             0
# 1003.0                 0            0       4221           2694             0
# 1005.0                 0            0        417            222             0
# 1007.0                 0            0        393            246             0
# 1009.0                 0            0       1523            395             0
#
#                                                                             \
# Candidate Chris Christie Donald Trump Hillary Clinton Jeb Bush John Kasich
# fips
# 1001.0                 0         5387            2387        0         421
# 1003.0                 0        23618            5290        0        2987
# 1005.0                 0         1710            2567        0         123
# 1007.0                 0         1959             942        0          84
# 1009.0                 0         7390             564        0         337
#
#                                                                              \
# Candidate Marco Rubio Martin O'Malley Mike Huckabee Rand Paul Rick Santorum
# fips
# 1001.0           1785               0             0         0             0
# 1003.0           9703               0             0         0             0
# 1005.0            498               0             0         0             0
# 1007.0            444               0             0         0             0
# 1009.0           1843               0             0         0             0
#
#
# Candidate Ted Cruz
# fips
# 1001.0        2482
# 1003.0        8571
# 1005.0         609
# 1007.0        1011
# 1009.0        3698

# %%
len(aaaa)
# Out:
# 4207

# %%
aaaa.sum()
# Out:
#        Candidate
# Votes   No Preference         8152
#         Uncommitted             43
#        Ben Carson           558044
#        Bernie Sanders     11807518
#        Carly Fiorina          3485
#        Chris Christie         3284
#        Donald Trump       13202135
#        Hillary Clinton    15597200
#        Jeb Bush              63101
#        John Kasich         4115040
#        Marco Rubio         3291044
#        Martin O'Malley         752
#        Mike Huckabee          3345
#        Rand Paul              8479
#        Rick Santorum          1782
#        Ted Cruz            7569817
# dtype: int64

# %%
#fips_merge_df = pd.merge(county_facts_cleaned_df, primary_results_cleaned_df, on="fips")

# %%
#len(fips_merge_df)

# %%
#fips_merge_df

# %%
#fips_merge_df.to_csv("training_data.csv", index=False, header=True)

# %%
#primary_results_df.head()

# %%
# primary_results_sorted = primary_results_df.sort_values(["fips", "votes"], ascending=True)
# primary_results_sorted.head()

# %%
len(primary_results_cleaned_df["Candidate"].unique())
# Out:
# 16

# %%
# primary_results_alabama_df = primary_results_df.loc[primary_results_df["state"] == "Alabama", :]
# primary_results_republican_df = primary_results_df.loc[primary_results_df["party"] == "Republican", :]
# primary_results_democrat_df = primary_results_df.loc[primary_results_df["party"] == "Democrat", :]
# primary_results_democrat_df.head()
# primary_results_democrat_sorted = primary_results_democrat_df.sort_values(["fips", "votes"], ascending=True)
# primary_results_democrat_sorted = primary_results_democrat_sorted.sort_values(["fips"], ascending=True)
# 8959 rows
# primary_results_democrat_sorted.nlargest(keep="last")
# primary_results_democrat_df.nlargest(100, ["fips", "votes"], keep="first")

# %%
#merge_02 = county_facts_cleaned.merge(primary_inverse, )

# %%
merge_02 = pd.merge(county_facts_cleaned_df, aaaa, left_on="fips", right_index=True)
merge_02.head()
# Out:
# C:\Users\cobin\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:544: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
#    fips          County  Population % Change  2010 Population  % Foreign Born  \
# 2  1001  Autauga County                  1.5            54571             1.6
# 3  1003  Baldwin County                  9.8           182265             3.6
# 4  1005  Barbour County                 -2.1            27457             2.9
# 5  1007     Bibb County                 -1.8            22915             1.2
# 6  1009   Blount County                  0.7            57322             4.3
#
#    Veterans  Mean Travel Time  Median Household Income  Below Poverty Level  \
# 2      5922              26.2                    53682                 12.1
# 3     19346              25.9                    50221                 13.9
# 4      2120              24.6                    32911                 26.7
# 5      1327              27.6                    36447                 18.1
# 6      4540              33.9                    44145                 15.8
#
#    Total Number of Firms        ...          (Votes, Donald Trump)  \
# 2                   4067        ...                           5387
# 3                  19035        ...                          23618
# 4                   1667        ...                           1710
# 5                   1385        ...                           1959
# 6                   4458        ...                           7390
#
#    (Votes, Hillary Clinton)  (Votes, Jeb Bush)  (Votes, John Kasich)  \
# 2                      2387                  0                   421
# 3                      5290                  0                  2987
# 4                      2567                  0                   123
# 5                       942                  0                    84
# 6                       564                  0                   337
#
#    (Votes, Marco Rubio)  (Votes, Martin O'Malley)  (Votes, Mike Huckabee)  \
# 2                  1785                         0                       0
# 3                  9703                         0                       0
# 4                   498                         0                       0
# 5                   444                         0                       0
# 6                  1843                         0                       0
#
#    (Votes, Rand Paul)  (Votes, Rick Santorum)  (Votes, Ted Cruz)
# 2                   0                       0               2482
# 3                   0                       0               8571
# 4                   0                       0                609
# 5                   0                       0               1011
# 6                   0                       0               3698
#
# [5 rows x 36 columns]

# %%
merge_02.columns
# Out:
# Index([                           'fips',                          'County',
#                    'Population % Change',                 '2010 Population',
#                         '% Foreign Born',                        'Veterans',
#                       'Mean Travel Time',         'Median Household Income',
#                    'Below Poverty Level',           'Total Number of Firms',
#                    '% Black-owned Firms',             '% Asian-owned Firms',
#                 '% Hispanic-owned Firms',             '% Women-owned Firms',
#        'Manufacturers Shipments ($1000)',            'Retail Sales ($1000)',
#                'Retail Sales per Capita',                'Building permits',
#               'Land Area (Square Miles)',      'Population per Square Mile',
#              ('Votes', ' No Preference'),         ('Votes', ' Uncommitted'),
#                  ('Votes', 'Ben Carson'),       ('Votes', 'Bernie Sanders'),
#               ('Votes', 'Carly Fiorina'),       ('Votes', 'Chris Christie'),
#                ('Votes', 'Donald Trump'),      ('Votes', 'Hillary Clinton'),
#                    ('Votes', 'Jeb Bush'),          ('Votes', 'John Kasich'),
#                 ('Votes', 'Marco Rubio'),      ('Votes', 'Martin O'Malley'),
#               ('Votes', 'Mike Huckabee'),            ('Votes', 'Rand Paul'),
#               ('Votes', 'Rick Santorum'),             ('Votes', 'Ted Cruz')],
#       dtype='object')

# %%
final_clean = merge_02.drop(columns=['County'])
final_clean.head()
# Out:
#    fips  Population % Change  2010 Population  % Foreign Born  Veterans  \
# 2  1001                  1.5            54571             1.6      5922
# 3  1003                  9.8           182265             3.6     19346
# 4  1005                 -2.1            27457             2.9      2120
# 5  1007                 -1.8            22915             1.2      1327
# 6  1009                  0.7            57322             4.3      4540
#
#    Mean Travel Time  Median Household Income  Below Poverty Level  \
# 2              26.2                    53682                 12.1
# 3              25.9                    50221                 13.9
# 4              24.6                    32911                 26.7
# 5              27.6                    36447                 18.1
# 6              33.9                    44145                 15.8
#
#    Total Number of Firms  % Black-owned Firms        ...          \
# 2                   4067                 15.2        ...
# 3                  19035                  2.7        ...
# 4                   1667                  0.0        ...
# 5                   1385                 14.9        ...
# 6                   4458                  0.0        ...
#
#    (Votes, Donald Trump)  (Votes, Hillary Clinton)  (Votes, Jeb Bush)  \
# 2                   5387                      2387                  0
# 3                  23618                      5290                  0
# 4                   1710                      2567                  0
# 5                   1959                       942                  0
# 6                   7390                       564                  0
#
#    (Votes, John Kasich)  (Votes, Marco Rubio)  (Votes, Martin O'Malley)  \
# 2                   421                  1785                         0
# 3                  2987                  9703                         0
# 4                   123                   498                         0
# 5                    84                   444                         0
# 6                   337                  1843                         0
#
#    (Votes, Mike Huckabee)  (Votes, Rand Paul)  (Votes, Rick Santorum)  \
# 2                       0                   0                       0
# 3                       0                   0                       0
# 4                       0                   0                       0
# 5                       0                   0                       0
# 6                       0                   0                       0
#
#    (Votes, Ted Cruz)
# 2               2482
# 3               8571
# 4                609
# 5               1011
# 6               3698
#
# [5 rows x 35 columns]

# %%
# Rename columns
merge_clean = final_clean.rename(columns={"('Votes', ' No Preference')": "No Pref",
                                       "('Votes', ' Uncommitted')": "Uncommitted",
                                       "('Votes', 'Ben Carson')": "Ben Carson",
                                       "('Votes', 'Bernie Sanders')": "Bernie Sanders",
                                       "('Votes', 'Carly Fiorina')": "Carly Fiorina",  
                                       "('Votes', 'Chris Christie')": "Chris Christie",
                                       "('Votes', 'Donald Trump')": "Donald Trump",
                                       "('Votes', 'Hillary Clinton')": "Hillary Clinton",
                                       "('Votes', 'Jeb Bush')":"Jeb Bush",       
                                       "('Votes', 'John Kasich')": "John Kasich",
                                       "('Votes', 'Marco Rubio')": "Marco Rubio",     
                                       "('Votes', 'Martin O'Malley')": "Martin O'Malley",
                                       "('Votes', 'Mike Huckabee')": "Mike Huckabee", 
                                       "('Votes', 'Rand Paul')": "Rand Paul",
                                       "('Votes', 'Rick Santorum')": "Rick Santorum",   
                                       "('Votes', 'Ted Cruz')": "Ted Cruz"})
merge_clean.head()
# Out:
#    fips  Population % Change  2010 Population  % Foreign Born  Veterans  \
# 2  1001                  1.5            54571             1.6      5922
# 3  1003                  9.8           182265             3.6     19346
# 4  1005                 -2.1            27457             2.9      2120
# 5  1007                 -1.8            22915             1.2      1327
# 6  1009                  0.7            57322             4.3      4540
#
#    Mean Travel Time  Median Household Income  Below Poverty Level  \
# 2              26.2                    53682                 12.1
# 3              25.9                    50221                 13.9
# 4              24.6                    32911                 26.7
# 5              27.6                    36447                 18.1
# 6              33.9                    44145                 15.8
#
#    Total Number of Firms  % Black-owned Firms        ...          \
# 2                   4067                 15.2        ...
# 3                  19035                  2.7        ...
# 4                   1667                  0.0        ...
# 5                   1385                 14.9        ...
# 6                   4458                  0.0        ...
#
#    (Votes, Donald Trump)  (Votes, Hillary Clinton)  (Votes, Jeb Bush)  \
# 2                   5387                      2387                  0
# 3                  23618                      5290                  0
# 4                   1710                      2567                  0
# 5                   1959                       942                  0
# 6                   7390                       564                  0
#
#    (Votes, John Kasich)  (Votes, Marco Rubio)  (Votes, Martin O'Malley)  \
# 2                   421                  1785                         0
# 3                  2987                  9703                         0
# 4                   123                   498                         0
# 5                    84                   444                         0
# 6                   337                  1843                         0
#
#    (Votes, Mike Huckabee)  (Votes, Rand Paul)  (Votes, Rick Santorum)  \
# 2                       0                   0                       0
# 3                       0                   0                       0
# 4                       0                   0                       0
# 5                       0                   0                       0
# 6                       0                   0                       0
#
#    (Votes, Ted Cruz)
# 2               2482
# 3               8571
# 4                609
# 5               1011
# 6               3698
#
# [5 rows x 35 columns]

# %%
merge_clean.columns
# Out:
# Index([                           'fips',             'Population % Change',
#                        '2010 Population',                  '% Foreign Born',
#                               'Veterans',                'Mean Travel Time',
#                'Median Household Income',             'Below Poverty Level',
#                  'Total Number of Firms',             '% Black-owned Firms',
#                    '% Asian-owned Firms',          '% Hispanic-owned Firms',
#                    '% Women-owned Firms', 'Manufacturers Shipments ($1000)',
#                   'Retail Sales ($1000)',         'Retail Sales per Capita',
#                       'Building permits',        'Land Area (Square Miles)',
#             'Population per Square Mile',       ('Votes', ' No Preference'),
#                ('Votes', ' Uncommitted'),           ('Votes', 'Ben Carson'),
#              ('Votes', 'Bernie Sanders'),        ('Votes', 'Carly Fiorina'),
#              ('Votes', 'Chris Christie'),         ('Votes', 'Donald Trump'),
#             ('Votes', 'Hillary Clinton'),             ('Votes', 'Jeb Bush'),
#                 ('Votes', 'John Kasich'),          ('Votes', 'Marco Rubio'),
#             ('Votes', 'Martin O'Malley'),        ('Votes', 'Mike Huckabee'),
#                   ('Votes', 'Rand Paul'),        ('Votes', 'Rick Santorum'),
#                    ('Votes', 'Ted Cruz')],
#       dtype='object')

# %%
clean = merge_clean.set_index('fips')
clean.head()
# Out:
#       Population % Change  2010 Population  % Foreign Born  Veterans  \
# fips
# 1001                  1.5            54571             1.6      5922
# 1003                  9.8           182265             3.6     19346
# 1005                 -2.1            27457             2.9      2120
# 1007                 -1.8            22915             1.2      1327
# 1009                  0.7            57322             4.3      4540
#
#       Mean Travel Time  Median Household Income  Below Poverty Level  \
# fips
# 1001              26.2                    53682                 12.1
# 1003              25.9                    50221                 13.9
# 1005              24.6                    32911                 26.7
# 1007              27.6                    36447                 18.1
# 1009              33.9                    44145                 15.8
#
#       Total Number of Firms  % Black-owned Firms  % Asian-owned Firms  \
# fips
# 1001                   4067                 15.2                  1.3
# 1003                  19035                  2.7                  1.0
# 1005                   1667                  0.0                  0.0
# 1007                   1385                 14.9                  0.0
# 1009                   4458                  0.0                  0.0
#
#             ...          (Votes, Donald Trump)  (Votes, Hillary Clinton)  \
# fips        ...
# 1001        ...                           5387                      2387
# 1003        ...                          23618                      5290
# 1005        ...                           1710                      2567
# 1007        ...                           1959                       942
# 1009        ...                           7390                       564
#
#       (Votes, Jeb Bush)  (Votes, John Kasich)  (Votes, Marco Rubio)  \
# fips
# 1001                  0                   421                  1785
# 1003                  0                  2987                  9703
# 1005                  0                   123                   498
# 1007                  0                    84                   444
# 1009                  0                   337                  1843
#
#       (Votes, Martin O'Malley)  (Votes, Mike Huckabee)  (Votes, Rand Paul)  \
# fips
# 1001                         0                       0                   0
# 1003                         0                       0                   0
# 1005                         0                       0                   0
# 1007                         0                       0                   0
# 1009                         0                       0                   0
#
#       (Votes, Rick Santorum)  (Votes, Ted Cruz)
# fips
# 1001                       0               2482
# 1003                       0               8571
# 1005                       0                609
# 1007                       0               1011
# 1009                       0               3698
#
# [5 rows x 34 columns]

# %%
clean.to_csv("nobetter.csv", index=False, header=True)

# %%
#primary_inverse = primary_results_df[["fips", "candidate", "votes"]]
